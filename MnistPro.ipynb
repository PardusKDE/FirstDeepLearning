# %%
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import Sequential
from keras.datasets import *
import cv2

# %%
(trainim, trainlab), (testim, testlab) = mnist.load_data()
# Out:
# ...
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
import matplotlib.pyplot as plt

# %%
model = Sequential()

# %%
model.add(Flatten())
model.add(Dense(128, activation="relu"))
model.add(Dense(128, activation="relu"))
model.add(Dense(10, activation="softmax"))

# %%
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# %%
model.fit(trainim, trainlab, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 1.6470 - accuracy: 0.8731
# Epoch 2/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3533 - accuracy: 0.9270
# Epoch 3/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2422 - accuracy: 0.9407
# Epoch 4/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1793 - accuracy: 0.9528
# Epoch 5/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1501 - accuracy: 0.9579
# Epoch 6/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1311 - accuracy: 0.9632
# Epoch 7/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1214 - accuracy: 0.9670
# Epoch 8/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1131 - accuracy: 0.9676
# Epoch 9/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0992 - accuracy: 0.9726
# Epoch 10/10
# ...

# %%
preX = model.predict(trainim)

# %%
import numpy as np

# %%
plt.title("Tahmin ve sonuc")
plt.imshow(trainim[6860])
plt.xlabel("Tahmin: {}".format(np.argmax(preX[6860])))
# Out:
# Text(0.5, 0, 'Tahmin: 2')
